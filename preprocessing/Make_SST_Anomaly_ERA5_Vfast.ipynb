# %% [markdown]
# ## Create Z500

# %%
import sys
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
#import collections
import pandas as pd
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

# import netCDF4
# from netCDF4 import *

import cartopy.crs as ccrs
import cartopy as cart
import cartopy.mpl.ticker as cticker
import cartopy.feature as cfeature
from scipy import interpolate
from scipy.interpolate import griddata
import time
import glob
import dask

from scipy.fftpack import fft
from scipy.fftpack import ifft
import copy
import eofs.standard as Eof_st
from matplotlib.colors import ListedColormap

from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter

import cmocean

# %%
if 'client' in locals():
    client.shutdown()
    print('...shutdown client...')
else:
    print('client does not exist yet')
# Out:
# client does not exist yet

# %%
from distributed import Client
from ncar_jobqueue import NCARCluster

cluster = NCARCluster(project='NAML0001',walltime='12:00:00')
cluster.scale(40)
client = Client(cluster)
client
# Out:
# /glade/u/apps/opt/conda/envs/npl-2023a/lib/python3.9/site-packages/dask_jobqueue/core.py:255: FutureWarning: job_extra has been renamed to job_extra_directives. You are still using it (even if only set to []; please also check config files). If you did not set job_extra_directives yet, job_extra will be respected for now, but it will be removed in a future release. If you already set job_extra_directives, job_extra is ignored and you can remove it.
#   warnings.warn(warn, FutureWarning)
# /glade/u/apps/opt/conda/envs/npl-2023a/lib/python3.9/site-packages/dask_jobqueue/core.py:274: FutureWarning: env_extra has been renamed to job_script_prologue. You are still using it (even if only set to []; please also check config files). If you did not set job_script_prologue yet, env_extra will be respected for now, but it will be removed in a future release. If you already set job_script_prologue, env_extra is ignored and you can remove it.
#   warnings.warn(warn, FutureWarning)
# /glade/u/apps/opt/conda/envs/npl-2023a/lib/python3.9/site-packages/dask_jobqueue/pbs.py:82: FutureWarning: project has been renamed to account as this kwarg was used wit -A option. You are still using it (please also check config files). If you did not set account yet, project will be respected for now, but it will be removed in a future release. If you already set account, project is ignored and you can remove it.
#   warnings.warn(warn, FutureWarning)
# /glade/u/apps/opt/conda/envs/npl-2023a/lib/python3.9/site-packages/dask_jobqueue/core.py:255: FutureWarning: job_extra has been renamed to job_extra_directives. You are still using it (even if only set to []; please also check config files). If you did not set job_extra_directives yet, job_extra will be respected for now, but it will be removed in a future release. If you already set job_extra_directives, job_extra is ignored and you can remove it.
#   warnings.warn(warn, FutureWarning)
# /glade/u/apps/opt/conda/envs/npl-2023a/lib/python3.9/site-packages/dask_jobqueue/core.py:274: FutureWarning: env_extra has been renamed to job_script_prologue. You are still using it (even if only set to []; please also check config files). If you did not set job_script_prologue yet, env_extra will be respected for now, but it will be removed in a future release. If you already set job_script_prologue, env_extra is ignored and you can remove it.
#   warnings.warn(warn, FutureWarning)
# /glade/u/apps/opt/conda/envs/npl-2023a/lib/python3.9/site-packages/dask_jobqueue/pbs.py:82: FutureWarning: project has been renamed to account as this kwarg was used wit -A option. You are still using it (please also check config files). If you did not set account yet, project will be respected for now, but it will be removed in a future release. If you already set account, project is ignored and you can remove it.
#   warnings.warn(warn, FutureWarning)
# <Client: 'tcp://10.12.206.35:34062' processes=0 threads=0, memory=0 B>

# %% [markdown]
# ## Useful Functions

# %%
#this functions pick data ranges out of an xarray data structure.
def is_dayofyear(dayofyear,dd):
    return (dayofyear==dd)

def is_dayofyear_range(dayofyear,dd1,dd2):
    
    if (dd2 > dd1) & (dd2<366) & (dd1>=1):
        return ((dayofyear>=dd1)&(dayofyear<=dd2))
    elif (dd2 > 366) & (dd1>0):
        dd2 = dd2 - 366
        print('you are wrapping around years... this is a warning if you arent intending to')
        return ((dayofyear>=dd1)|(dayofyear<=dd2))
    elif dd1 < 1:
        print('you are wrapping around years... this is a warning if you arent intending to')
        dd1 = dd1+366
        return ((dayofyear>=dd1)|(dayofyear<=dd2))
    else:
        print('this is an edge case you did not foresee')
        return np.nan
    
def cal_ano_dcli(var):
    '''return [var_ano, var_dcli], Taxis= axis of time'''
    var_dcli=var.groupby('time.dayofyear').mean(dim='time')
    var_ano= var - var.mean(dim = 'time')
    
    return var_ano, var_dcli




#make MJO base line months
def is_NDJFM(dayofyear):
    return ((dayofyear==11)|(dayofyear==12)|(dayofyear==1)|(dayofyear==2)|(dayofyear==3))



def is_doyrange(doy,dd,tod,hh):
    daywind = 15
    if (dd - daywind) < 1:
        # print('in 1')
        return ((doy >= (366+(dd-daywind))) | (doy <= dd+daywind)) & (tod==hh)
        
    elif (dd + daywind) > 366:
        # print('in 2')
        return ((((doy <= 366) & (doy>=(dd-daywind))) | (doy <= (-1*((366-(dd-daywind))-(2*daywind)))  )))&(tod==hh)
    
    else:
        # print('in 3')
        return ((doy >= dd-daywind) & (doy <= dd+daywind))&(tod==hh)
    

# def is_NDJFM(dayofyear):
#     return ((dayofyear==12)|(dayofyear==1)|(dayofyear==2))

# def is_NDJFM(dayofyear):
#     return ((dayofyear==1)|(dayofyear==2)|(dayofyear==3)|(dayofyear==4)|(dayofyear==5)|(dayofyear==6)|(dayofyear==7)|(dayofyear==8)|(dayofyear==9)|(dayofyear==10)|(dayofyear==11)|(dayofyear==12))

#  NDJFM_data = GPH_E20c.sel(time=is_NDJFM(GPH_E20c['time.month']))

# %% [markdown]
# ## First Load the ERA5 Data

# %%
# %%time
FNS_all = sorted(glob.glob('/glade/scratch/wchapman/ERA5_uvolr/1deg/*_sstk*'))
DSz500 =  xr.open_mfdataset(FNS_all,parallel=True)

DSz500 = DSz500.chunk(chunks={'time':100,'lat':192,'lon':288})

DSz500=DSz500.convert_calendar("standard", use_cftime=True)
print('....loading....')
DSz500=DSz500.load()
# Out:
# ....loading....
# CPU times: user 2min 3s, sys: 6.97 s, total: 2min 10s
# Wall time: 2min 16s

# %% [markdown]
# ## Make Climatology
# - This takes about 1000 years.. it's better to just load the files if they have already been made

# %%
# %%time

def is_doyrange(doy,dd,tod,hh):
    daywind = 15
    if (dd - daywind) < 1:
        # print('in 1')
        return ((doy >= (366+(dd-daywind))) | (doy <= dd+daywind)) & (tod==hh)
        
    elif (dd + daywind) > 366:
        # print('in 2')
        return ((((doy <= 366) & (doy>=(dd-daywind))) | (doy <= (-1*((366-(dd-daywind))-(2*daywind)))  )))&(tod==hh)
    
    else:
        # print('in 3')
        return ((doy >= dd-daywind) & (doy <= dd+daywind))&(tod==hh)


Z500_climo = xr.zeros_like(DSz500['SSTK'])
print('... creating climo from centered 30 day average ...')
for ee,dayhr in (enumerate(DSz500.time)):
    if ee%1 ==0:
        print('doing ',ee,' of 365')
    dooDOY = dayhr['time.dayofyear']
    hh=dayhr['time.hour']
    Dtemp = DSz500.sel(time=is_doyrange(DSz500['time.dayofyear'],dooDOY,DSz500['time.hour'],hh))[['SSTK']].mean(['time'])
    Z500_climo[ee,:,:] = Dtemp['SSTK'].values
    
    if ee == (365)+8:
        endee=ee
        enddate = dayhr
        break

print("this is much faster but only works with noleap calendar:")  
svname = '/glade/scratch/wchapman/data_for_KJM//'+'SSTK_ERA5_1975_2022_WEC_repeats.nc'
DSz500.to_netcdf(svname)
print('otherwise you have to do this: (uncomment below)')

print('...now repeating climo...') 
for ee,dayhr in (enumerate(DSz500.time)):
    dm = dayhr['time.month'].values
    dd = dayhr['time.day'].values
    dy = DSz500['time.year'][0].values

    getday = f'{dy:04}'+'-'+f'{dm:02}'+'-'+f'{dd:02}'
    
    #leap year shenanigans:
    if f'{dm:02}'+'-'+f'{dd:02}' == '02-29': 
        getday = f'{dy:04}'+'-02-28'
        
    if ee%500 ==0:
        print('doing ',ee,' of ', len(DSz500['time']))
    try:
        DtempZ500 = Z500_climo.sel(time=getday).squeeze()
    except: 
        DtempZ500 = Z500_climo.sel(time=getday,method='nearest').squeeze()
    Z500_climo[ee,:,:] = DtempZ500.values
    
DSz500['SSTK_climo'] = Z500_climo

svname = '/glade/scratch/wchapman/data_for_KJM/'+'SSTK_ERA5_1975_2022_WEC.nc'
DSz500.to_netcdf(svname)
# Out:
# ... creating climo from centered 30 day average ...
# doing  0  of 365
# doing  1  of 365
# doing  2  of 365
# doing  3  of 365
# doing  4  of 365
# doing  5  of 365
# doing  6  of 365
# doing  7  of 365
# doing  8  of 365
# doing  9  of 365
# doing  10  of 365
# doing  11  of 365
# doing  12  of 365
# doing  13  of 365
# doing  14  of 365
# doing  15  of 365
# doing  16  of 365
# doing  17  of 365
# doing  18  of 365
# doing  19  of 365
# doing  20  of 365
# doing  21  of 365
# doing  22  of 365
# doing  23  of 365
# doing  24  of 365
# doing  25  of 365
# doing  26  of 365
# doing  27  of 365
# doing  28  of 365
# doing  29  of 365
# doing  30  of 365
# doing  31  of 365
# doing  32  of 365
# doing  33  of 365
# doing  34  of 365
# doing  35  of 365
# doing  36  of 365
# doing  37  of 365
# doing  38  of 365
# doing  39  of 365
# doing  40  of 365
# doing  41  of 365
# doing  42  of 365
# doing  43  of 365
# doing  44  of 365
# doing  45  of 365
# doing  46  of 365
# doing  47  of 365
# doing  48  of 365
# doing  49  of 365
# doing  50  of 365
# doing  51  of 365
# doing  52  of 365
# doing  53  of 365
# doing  54  of 365
# doing  55  of 365
# doing  56  of 365
# doing  57  of 365
# doing  58  of 365
# doing  59  of 365
# doing  60  of 365
# doing  61  of 365
# doing  62  of 365
# doing  63  of 365
# doing  64  of 365
# doing  65  of 365
# doing  66  of 365
# doing  67  of 365
# doing  68  of 365
# doing  69  of 365
# doing  70  of 365
# doing  71  of 365
# doing  72  of 365
# doing  73  of 365
# doing  74  of 365
# doing  75  of 365
# doing  76  of 365
# doing  77  of 365
# doing  78  of 365
# doing  79  of 365
# doing  80  of 365
# doing  81  of 365
# doing  82  of 365
# doing  83  of 365
# doing  84  of 365
# doing  85  of 365
# doing  86  of 365
# doing  87  of 365
# doing  88  of 365
# doing  89  of 365
# doing  90  of 365
# doing  91  of 365
# doing  92  of 365
# doing  93  of 365
# doing  94  of 365
# doing  95  of 365
# doing  96  of 365
# doing  97  of 365
# doing  98  of 365
# doing  99  of 365
# doing  100  of 365
# doing  101  of 365
# doing  102  of 365
# doing  103  of 365
# doing  104  of 365
# doing  105  of 365
# doing  106  of 365
# doing  107  of 365
# doing  108  of 365
# doing  109  of 365
# doing  110  of 365
# doing  111  of 365
# doing  112  of 365
# doing  113  of 365
# doing  114  of 365
# doing  115  of 365
# doing  116  of 365
# doing  117  of 365
# doing  118  of 365
# doing  119  of 365
# doing  120  of 365
# doing  121  of 365
# doing  122  of 365
# doing  123  of 365
# doing  124  of 365
# doing  125  of 365
# doing  126  of 365
# doing  127  of 365
# doing  128  of 365
# doing  129  of 365
# doing  130  of 365
# doing  131  of 365
# doing  132  of 365
# doing  133  of 365
# doing  134  of 365
# doing  135  of 365
# doing  136  of 365
# doing  137  of 365
# doing  138  of 365
# doing  139  of 365
# doing  140  of 365
# doing  141  of 365
# doing  142  of 365
# doing  143  of 365
# doing  144  of 365
# doing  145  of 365
# doing  146  of 365
# doing  147  of 365
# doing  148  of 365
# doing  149  of 365
# doing  150  of 365
# doing  151  of 365
# doing  152  of 365
# doing  153  of 365
# doing  154  of 365
# doing  155  of 365
# doing  156  of 365
# doing  157  of 365
# doing  158  of 365
# doing  159  of 365
# doing  160  of 365
# doing  161  of 365
# doing  162  of 365
# doing  163  of 365
# doing  164  of 365
# doing  165  of 365
# doing  166  of 365
# doing  167  of 365
# doing  168  of 365
# doing  169  of 365
# doing  170  of 365
# doing  171  of 365
# doing  172  of 365
# doing  173  of 365
# doing  174  of 365
# doing  175  of 365
# doing  176  of 365
# doing  177  of 365
# doing  178  of 365
# doing  179  of 365
# doing  180  of 365
# doing  181  of 365
# doing  182  of 365
# doing  183  of 365
# doing  184  of 365
# doing  185  of 365
# doing  186  of 365
# doing  187  of 365
# doing  188  of 365
# doing  189  of 365
# doing  190  of 365
# doing  191  of 365
# doing  192  of 365
# doing  193  of 365
# doing  194  of 365
# doing  195  of 365
# doing  196  of 365
# doing  197  of 365
# doing  198  of 365
# doing  199  of 365
# doing  200  of 365
# doing  201  of 365
# doing  202  of 365
# doing  203  of 365
# doing  204  of 365
# doing  205  of 365
# doing  206  of 365
# doing  207  of 365
# doing  208  of 365
# doing  209  of 365
# doing  210  of 365
# doing  211  of 365
# doing  212  of 365
# doing  213  of 365
# doing  214  of 365
# doing  215  of 365
# doing  216  of 365
# doing  217  of 365
# doing  218  of 365
# doing  219  of 365
# doing  220  of 365
# doing  221  of 365
# doing  222  of 365
# doing  223  of 365
# doing  224  of 365
# doing  225  of 365
# doing  226  of 365
# doing  227  of 365
# doing  228  of 365
# doing  229  of 365
# doing  230  of 365
# doing  231  of 365
# doing  232  of 365
# doing  233  of 365
# doing  234  of 365
# doing  235  of 365
# doing  236  of 365
# doing  237  of 365
# doing  238  of 365
# doing  239  of 365
# doing  240  of 365
# doing  241  of 365
# doing  242  of 365
# doing  243  of 365
# doing  244  of 365
# doing  245  of 365
# doing  246  of 365
# doing  247  of 365
# doing  248  of 365
# doing  249  of 365
# doing  250  of 365
# doing  251  of 365
# doing  252  of 365
# doing  253  of 365
# doing  254  of 365
# doing  255  of 365
# doing  256  of 365
# doing  257  of 365
# doing  258  of 365
# doing  259  of 365
# doing  260  of 365
# doing  261  of 365
# doing  262  of 365
# doing  263  of 365
# doing  264  of 365
# doing  265  of 365
# doing  266  of 365
# doing  267  of 365
# doing  268  of 365
# doing  269  of 365
# doing  270  of 365
# doing  271  of 365
# doing  272  of 365
# doing  273  of 365
# doing  274  of 365
# doing  275  of 365
# doing  276  of 365
# doing  277  of 365
# doing  278  of 365
# doing  279  of 365
# doing  280  of 365
# doing  281  of 365
# doing  282  of 365
# doing  283  of 365
# doing  284  of 365
# doing  285  of 365
# doing  286  of 365
# doing  287  of 365
# doing  288  of 365
# doing  289  of 365
# doing  290  of 365
# doing  291  of 365
# doing  292  of 365
# doing  293  of 365
# doing  294  of 365
# doing  295  of 365
# doing  296  of 365
# doing  297  of 365
# doing  298  of 365
# doing  299  of 365
# doing  300  of 365
# doing  301  of 365
# doing  302  of 365
# doing  303  of 365
# doing  304  of 365
# doing  305  of 365
# doing  306  of 365
# doing  307  of 365
# doing  308  of 365
# doing  309  of 365
# doing  310  of 365
# doing  311  of 365
# doing  312  of 365
# doing  313  of 365
# doing  314  of 365
# doing  315  of 365
# doing  316  of 365
# doing  317  of 365
# doing  318  of 365
# doing  319  of 365
# doing  320  of 365
# doing  321  of 365
# doing  322  of 365
# doing  323  of 365
# doing  324  of 365
# doing  325  of 365
# doing  326  of 365
# doing  327  of 365
# doing  328  of 365
# doing  329  of 365
# doing  330  of 365
# doing  331  of 365
# doing  332  of 365
# doing  333  of 365
# doing  334  of 365
# doing  335  of 365
# doing  336  of 365
# doing  337  of 365
# doing  338  of 365
# doing  339  of 365
# doing  340  of 365
# doing  341  of 365
# doing  342  of 365
# doing  343  of 365
# doing  344  of 365
# doing  345  of 365
# doing  346  of 365
# doing  347  of 365
# doing  348  of 365
# doing  349  of 365
# doing  350  of 365
# doing  351  of 365
# doing  352  of 365
# doing  353  of 365
# doing  354  of 365
# doing  355  of 365
# doing  356  of 365
# doing  357  of 365
# doing  358  of 365
# doing  359  of 365
# doing  360  of 365
# doing  361  of 365
# doing  362  of 365
# doing  363  of 365
# doing  364  of 365
# doing  365  of 365
# doing  366  of 365
# doing  367  of 365
# doing  368  of 365
# doing  369  of 365
# doing  370  of 365
# doing  371  of 365
# doing  372  of 365
# doing  373  of 365
# this is much faster but only works with noleap calendar:
# otherwise you have to do this: (uncomment below)
# ...now repeating climo...
# doing  0  of  17897
# doing  500  of  17897
# doing  1000  of  17897
# doing  1500  of  17897
# doing  2000  of  17897
# doing  2500  of  17897
# doing  3000  of  17897
# doing  3500  of  17897
# doing  4000  of  17897
# doing  4500  of  17897
# doing  5000  of  17897
# doing  5500  of  17897
# doing  6000  of  17897
# doing  6500  of  17897
# doing  7000  of  17897
# doing  7500  of  17897
# doing  8000  of  17897
# doing  8500  of  17897
# doing  9000  of  17897
# doing  9500  of  17897
# doing  10000  of  17897
# doing  10500  of  17897
# doing  11000  of  17897
# doing  11500  of  17897
# doing  12000  of  17897
# doing  12500  of  17897
# doing  13000  of  17897
# doing  13500  of  17897
# doing  14000  of  17897
# doing  14500  of  17897
# doing  15000  of  17897
# doing  15500  of  17897
# doing  16000  of  17897
# doing  16500  of  17897
# doing  17000  of  17897
# doing  17500  of  17897
# CPU times: user 11min 56s, sys: 1min 7s, total: 13min 3s
# Wall time: 13min 23s

# %% [markdown]
# ## Hacky Climo Way

# %%
Z500S_climo = xr.open_dataset('/glade/scratch/wchapman/data_for_KJM//'+'Z500_CESM2_100_400_climo.nc')
DSjustclim = Z500S_climo['Z500'][:380,:,:]
Z500_climo = xr.zeros_like(DSz500['Z500'])

# %%
print("this is much faster but only works with noleap calendar:")  
Z500np = np.array(DSjustclim[:365,:,:])
print('...expand...')
arrays_to_concat = [Z500np] * 300
print('...done expand...')
concatenated_arr = np.concatenate(arrays_to_concat, axis=0)
Z500_climo[:,:,:]=concatenated_arr
dr = pd.date_range(start='1801-01-01', end='2100-12-31', freq='D')
dates = dr[(dr.day != 29) | (dr.month != 2)]
DSz500['Z500_climo'] = Z500_climo
DSz500['time']=dates
print('...saving...')
svname = '/glade/scratch/wchapman/data_for_KJM//'+'Z500_CESM2_100_400_repeats.nc'
DSz500.to_netcdf(svname)
# Out:
# this is much faster but only works with noleap calendar:
# ...expand...
# ...done expand...
# ...saving...

# %% [markdown]
# ## For Tony to do.. Create your anomaly:
# - subtract Z500_climo from Z500 and save a new variable Z500a
# - Take and average over the north Pacific (lat[20,70],lon[150-240])
# - - This will make the "index" of interest
